# %%
import os
import numpy as np
import pandas as pd

path = os.getcwd()
pathTrain = os.path.join(path,'figures')
pathTest = os.path.join(path,'figures-test')

# %%
labelsList=pd.read_csv('/Users/jieunyoo/april12_3dCNN/labels.csv')
labelsList
# Out:
#     cotBeta
# 0 -0.113275
# 1  0.014357
# 2  0.055306
# 3  0.212336
# 4 -0.094988
# 5  0.102393
# 6  0.198032
# 7 -0.017283
# 8  0.097988
# 9  0.224303

# %%
labelsListTest=pd.read_csv('/Users/jieunyoo/april12_3dCNN/labelsTest.csv')
labelsListTest
# Out:
#     cotBeta
# 0 -0.070380
# 1  0.041277
# 2 -0.056348
# 3  0.236056
# 4 -0.155919
# 5  0.189536
# 6  0.217438
# 7  0.113703
# 8  0.211178
# 9 -0.234857

# %%
#get file lists for training
cluster_directory_list = os.listdir('/Users/jieunyoo/april12_3dCNN/figures')

for index1, data_dir in enumerate(cluster_directory_list):
    clusterpath = os.path.join(pathTrain,data_dir)
    print(clusterpath)
    img_list = os.listdir(os.path.join(clusterpath))
    img_list.sort()

    train_df = pd.DataFrame(columns=['FileName'])
    for frame in img_list:
        frame_list = os.path.join(clusterpath,frame)
        train_df = train_df.append({'FileName': frame_list},ignore_index=True)
   
    file_name='{}.csv'.format(data_dir)
    train_df.to_csv('/Users/jieunyoo/april12_3dCNN/data_files/train/{}'.format(file_name),index=False)
# Out:
# /Users/jieunyoo/april12_3dCNN/figures/cluster7
# /Users/jieunyoo/april12_3dCNN/figures/cluster0
# /Users/jieunyoo/april12_3dCNN/figures/cluster9
# /Users/jieunyoo/april12_3dCNN/figures/cluster8
# /Users/jieunyoo/april12_3dCNN/figures/cluster1
# /Users/jieunyoo/april12_3dCNN/figures/cluster6
# /Users/jieunyoo/april12_3dCNN/figures/cluster3
# /Users/jieunyoo/april12_3dCNN/figures/cluster4
# /Users/jieunyoo/april12_3dCNN/figures/cluster5
# /Users/jieunyoo/april12_3dCNN/figures/cluster2

# %%
#get file lists for testing
cluster_directory_listTest = os.listdir('/Users/jieunyoo/april12_3dCNN/figures-test')
print(cluster_directory_listTest)
for index1, data_dir in enumerate(cluster_directory_listTest):
    clusterpathTest = os.path.join(pathTest,data_dir)
    img_list = os.listdir(os.path.join(clusterpathTest))
    img_list.sort()
    test_df = pd.DataFrame(columns=['FileName'])
    for frame in img_list:
        frame_list = os.path.join(clusterpath,frame)
        test_df = test_df.append({'FileName': frame_list},ignore_index=True)
    file_name='{}.csv'.format(data_dir)
    test_df.to_csv('/Users/jieunyoo/april12_3dCNN/data_files/test/{}'.format(file_name),index=False)
# Out:
# ['cluster7', 'cluster0', 'cluster9', 'cluster8', 'cluster1', 'cluster6', 'cluster3', 'cluster4', 'cluster5', 'cluster2']

# %%
#train
cotBeta = labelsList.to_numpy()
print(cotBeta)
# Out:
# [[-0.11327452]
#  [ 0.01435729]
#  [ 0.05530644]
#  [ 0.21233614]
#  [-0.09498768]
#  [ 0.10239282]
#  [ 0.1980316 ]
#  [-0.01728322]
#  [ 0.09798768]
#  [ 0.22430264]]

# %%
#test
cotBetaTest = labelsListTest.to_numpy()
print(cotBetaTest)
# Out:
# [[-0.07037991]
#  [ 0.0412773 ]
#  [-0.05634755]
#  [ 0.23605609]
#  [-0.15591939]
#  [ 0.18953598]
#  [ 0.21743795]
#  [ 0.11370337]
#  [ 0.21117846]
#  [-0.23485704]]

# %%
#append cotBeta label (for training)
for index,file in enumerate(cluster_directory_list):
    label = cotBeta[index][0]
    temporaryList=np.repeat(label,8)
    temporaryDF = pd.DataFrame(temporaryList, columns=['label'])
       
    file_name='{}.csv'.format(index)
    temporary1 = pd.read_csv('/Users/jieunyoo/april12_3dCNN/data_files/train/cluster{}'.format(file_name))
    result = pd.concat([temporary1,temporaryDF],axis=1)
    print(result)
    result.to_csv('/Users/jieunyoo/april12_3dCNN/data_files/train/cluster{}'.format(file_name),index=False)
# Out:
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster0... -0.113275
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster1...  0.014357
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.055306
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster3...  0.212336
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster4... -0.094988
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster5...  0.102393
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster6...  0.198032
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster7... -0.017283
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster8...  0.097988
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster9...  0.224303

# %%
#append cotBeta label (for testing)
for index,file in enumerate(cluster_directory_listTest):
    label = cotBetaTest[index][0]
    temporaryList=np.repeat(label,8)
    temporaryDF = pd.DataFrame(temporaryList, columns=['label'])
       
    file_name='{}.csv'.format(index)
    temporary1 = pd.read_csv('/Users/jieunyoo/april12_3dCNN/data_files/test/cluster{}'.format(file_name))
    result = pd.concat([temporary1,temporaryDF],axis=1)
    print(result)
    result.to_csv('/Users/jieunyoo/april12_3dCNN/data_files/test/cluster{}'.format(file_name),index=False)
# Out:
#                                             FileName    label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.07038
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.041277
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.056348
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.236056
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.155919
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.189536
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.217438
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.113703
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2...  0.211178
#                                             FileName     label
# 0  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 1  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 2  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 3  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 4  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 5  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 6  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
# 7  /Users/jieunyoo/april12_3dCNN/figures/cluster2... -0.234857
