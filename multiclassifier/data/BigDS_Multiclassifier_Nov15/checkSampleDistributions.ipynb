# %%
import pandas as pd

# %%
df1 = pd.read_csv('/uscms/home/jieun201/nobackup/YOURWORKINGAREA/nov12_multiclassifier_balancePT/TestSetLabel.csv')
df1.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'ptLabel'}>]], dtype=object)

# %%
df2 = pd.read_csv('/uscms/home/jieun201/nobackup/YOURWORKINGAREA/nov12_multiclassifier_balancePT/TrainSetLabel.csv')
df2.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'ptLabel'}>]], dtype=object)

# %%
df3 = pd.read_csv('/uscms/home/jieun201/nobackup/YOURWORKINGAREA/nov12_multiclassifier_balancePT/y-localTest.csv')
df3.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'y-local'}>]], dtype=object)

# %%
df4 = pd.read_csv('/uscms/home/jieun201/nobackup/YOURWORKINGAREA/nov12_multiclassifier_balancePT/y-localTrain.csv')
df4.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'y-local'}>]], dtype=object)
